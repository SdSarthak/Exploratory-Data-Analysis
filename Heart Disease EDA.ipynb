# %% [markdown]
# # **Import Libraries and Data**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
heart_disease = fetch_ucirepo(id=45)

# data (as pandas dataframes)
X = heart_disease.data.features
y = heart_disease.data.targets

# metadata
print(heart_disease.metadata)
# Out:
# {'uci_id': 45, 'name': 'Heart Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/45/heart+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/45/data.csv', 'abstract': '4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 303, 'num_features': 13, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['num'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1989, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C52P4X', 'creators': ['Andras Janosi', 'William Steinbrunn', 'Matthias Pfisterer', 'Robert Detrano'], 'intro_paper': {'ID': 231, 'type': 'NATIVE', 'title': 'International application of a new probability algorithm for the diagnosis of coronary artery disease.', 'authors': 'R. Detrano, A. Jánosi, W. Steinbrunn,
# ...

# %%
# variable information
print(heart_disease.variables)
# Out:
#         name     role         type demographic  \
# 0        age  Feature      Integer         Age
# 1        sex  Feature  Categorical         Sex
# 2         cp  Feature  Categorical        None
# 3   trestbps  Feature      Integer        None
# 4       chol  Feature      Integer        None
# 5        fbs  Feature  Categorical        None
# 6    restecg  Feature  Categorical        None
# 7    thalach  Feature      Integer        None
# 8      exang  Feature  Categorical        None
# 9    oldpeak  Feature      Integer        None
# 10     slope  Feature  Categorical        None
# 11        ca  Feature      Integer        None
# 12      thal  Feature  Categorical        None
# 13       num   Target      Integer        None
#
#                                           description  units missing_values
# 0                                                None  years             no
# 1                                                None   None             no
# ...

# %%
data = pd.concat([X, y], axis=1)
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  num
# 0  0.0   6.0    0
# 1  3.0   3.0    2
# 2  2.0   7.0    1
# 3  0.0   3.0    0
# 4  0.0   3.0    0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
#  13  num       303 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 33.3 KB

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %% [markdown]
# # **Cleaning**

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# num         0
# dtype: int64

# %%
data_cleaned = data.dropna(axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
#  13  num       303 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 33.3 KB

# %% [markdown]
# # **Visualisation**

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='num', data=data_cleaned)
plt.title('Distribution of Heart Disease (0: No Disease, 1: Disease)')
plt.xlabel('Heart Disease Diagnosis')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12, 8))
correlation = data_cleaned.corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(data_cleaned, hue='num', diag_kind='kde')
plt.title('Pairplot of Heart Disease Features')
plt.show()

# %% [markdown]
# #**Feature Distribution Analysis**

# %% [markdown]
# Age Distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data_cleaned['age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Gender

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=data_cleaned)
plt.title('Sex Distribution')
plt.xlabel('Sex (0: Female, 1: Male)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Chest Pain

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='cp', data=data_cleaned)
plt.title('Chest Pain Types Distribution')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.show()

# %%
numerical_features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='num', y=feature, data=data_cleaned)
    plt.title(f'{feature} by Heart Disease Diagnosis')
    plt.xlabel('Heart Disease Diagnosis')
    plt.ylabel(feature)
    plt.show()

# %% [markdown]
# #**Conclusion**

# %%
avg_features = data_cleaned.groupby('num').mean().T
avg_features.plot(kind='bar', figsize=(12, 6))
plt.title('Average Feature Values Based on Heart Disease Diagnosis')
plt.xlabel('Features')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='num', y='age', data=data_cleaned)
plt.title('Age Distribution by Heart Disease Diagnosis')
plt.xlabel('Heart Disease Diagnosis')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=correlation['num'].drop('num').index, y=correlation['num'].drop('num').values)
plt.title('Correlation of Features with Heart Disease Diagnosis')
plt.xlabel('Features')
plt.ylabel('Correlation Coefficient')
plt.xticks(rotation=45)
plt.show()
