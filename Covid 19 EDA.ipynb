# %% [markdown]
# # **Import Libraries and Dataset**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'
data = pd.read_csv(url)

# %%
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429435 entries, 0 to 429434
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    429435 non-null  object
#  1   continent                                   402910 non-null  object
#  2   location                                    429435 non-null  object
#  3   date                                        429435 non-null  object
#  4   total_cases                                 411804 non-null  float64
#  5   new_cases                                   410159 non-null  float64
#  6   new_cases_smoothed                          408929 non-null  float64
#  7   total_deaths                                411804 non-null  float64
#  8   new_deaths                                  410608 non-null  float64
# ...

# %%
data.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  4.118040e+05  4.101590e+05        4.089290e+05  4.118040e+05
# mean   7.365292e+06  8.017360e+03        8.041026e+03  8.125957e+04
# std    4.477582e+07  2.296649e+05        8.661611e+04  4.411901e+05
# min    0.000000e+00  0.000000e+00        0.000000e+00  0.000000e+00
# 25%    6.280750e+03  0.000000e+00        0.000000e+00  4.300000e+01
# 50%    6.365300e+04  0.000000e+00        1.200000e+01  7.990000e+02
# 75%    7.582720e+05  0.000000e+00        3.132860e+02  9.574000e+03
# max    7.758668e+08  4.423623e+07        6.319461e+06  7.057132e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  410608.000000        409378.000000            411804.000000
# mean       71.852139            72.060873            112096.199396
# std      1368.322990           513.636567            162240.412419
# min         0.000000             0.000000                 0.000000
# ...

# %%
data.shape
# Out:
# (429435, 67)

# %%
# Check for missing values before cleaning
print("\nMissing values before cleaning:")
print(data.isnull().sum().sort_values(ascending=False))
# Out:
# Missing values before cleaning:
# weekly_icu_admissions_per_million          418442
# weekly_icu_admissions                      418442
# excess_mortality_cumulative_per_million    416024
# excess_mortality                           416024
# excess_mortality_cumulative                416024
#                                             ...
# total_deaths                                17631
# population                                      0
# date                                            0
# location                                        0
# iso_code                                        0
# Length: 67, dtype: int64

# %%
# Check for duplicates
duplicates = data.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicates}")
data_cleaned = data.dropna(axis=1, how='any')
#Remove them
if duplicates > 0:
    data = data.drop_duplicates()
    print(f"Duplicates removed. New number of rows: {data.shape[0]}")
# Out:
# Number of duplicate rows: 0

# %%
# Select essential columns to keep
essential_columns = ['date', 'location', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths']
data_essential = data[essential_columns]

# %%
# Drop rows with NaN in essential columns only
data_cleaned = data_essential.dropna(subset=essential_columns)

# %%
data_cleaned.shape
# Out:
# (410147, 6)

# %%
data_cleaned.isnull().sum().sort_values(ascending=False)
# Out:
# date            0
# location        0
# total_cases     0
# new_cases       0
# total_deaths    0
# new_deaths      0
# dtype: int64

# %%
# Convert 'date' column to datetime format if it exists
if 'date' in data_cleaned.columns:
    data_cleaned['date'] = pd.to_datetime(data_cleaned['date'])
# Out:
# <ipython-input-13-1e072d94004b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['date'] = pd.to_datetime(data_cleaned['date'])

# %%
# Reset the index of the cleaned DataFrame
data_cleaned.reset_index(drop=True, inplace=True)

# %%
data_cleaned.describe()
# Out:
#                                 date   total_cases     new_cases  \
# count                         410147  4.101470e+05  4.101470e+05
# mean   2022-04-17 23:40:41.812325888  7.195123e+06  8.017480e+03
# min              2020-01-05 00:00:00  0.000000e+00  0.000000e+00
# 25%              2021-02-24 00:00:00  6.246000e+03  0.000000e+00
# 50%              2022-04-17 00:00:00  6.279100e+04  0.000000e+00
# 75%              2023-06-08 00:00:00  7.294750e+05  0.000000e+00
# max              2024-08-04 00:00:00  7.758668e+08  4.423623e+07
# std                              NaN  4.473291e+07  2.296682e+05
#
#        total_deaths     new_deaths
# count  4.101470e+05  410147.000000
# mean   7.988650e+04      71.761829
# min    0.000000e+00       0.000000
# 25%    4.200000e+01       0.000000
# 50%    7.780000e+02       0.000000
# 75%    9.366000e+03       0.000000
# max    7.057132e+06  103719.000000
# std    4.406309e+05    1369.002310

# %% [markdown]
# # **Visualisation**

# %% [markdown]
# **Distribution of total cases per country**

# %%
plt.figure(figsize=(12, 6))
top_countries = data_cleaned.groupby('location')['total_cases'].max().nlargest(10).index
sns.barplot(data=data_cleaned[data_cleaned['location'].isin(top_countries)],
             x='total_cases',
             y='location',
             estimator=max,
             palette='viridis')
plt.title('Top 10 Countries by Total COVID-19 Cases')
plt.xlabel('Total Cases')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-16-e80f29b05be2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data_cleaned[data_cleaned['location'].isin(top_countries)],

# %% [markdown]
# **The trend of cases over time for a specific country**

# %%
usa_data = data_cleaned[data_cleaned['location'] == 'United States']
plt.figure(figsize=(14, 7))
sns.lineplot(data=usa_data, x='date', y='total_cases', marker='o', label='Total Cases')
sns.lineplot(data=usa_data, x='date', y='total_deaths', marker='o', label='Total Deaths', color='red')
plt.title('COVID-19 Cases and Deaths in the USA Over Time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
# Correlation heatmap for numerical features
plt.figure(figsize=(10, 8))

# Select only numerical columns for correlation
numerical_data = data_cleaned.select_dtypes(include=['float64', 'int64'])
if not numerical_data.empty:
    correlation = numerical_data.corr()
    sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
    plt.title('Correlation Heatmap of Numerical Features')
else:
    print("No numerical data available for correlation analysis.")

plt.tight_layout()
plt.show()

# %%
# Aggregate total cases and total deaths by date for visualization
conclusion_data = data_cleaned.groupby('date').agg({
    'total_cases': 'sum',
    'total_deaths': 'sum'
}).reset_index()

# %% [markdown]
# #**Conclusion**

# %%
plt.figure(figsize=(14, 7))
sns.lineplot(data=conclusion_data, x='date', y='total_cases', marker='*', label='Total Cases', color='blue')
sns.lineplot(data=conclusion_data, x='date', y='total_deaths', marker='*', label='Total Deaths', color='red')
plt.title('Total COVID-19 Cases and Deaths Over Time Globally')
plt.xlabel('Date')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()
